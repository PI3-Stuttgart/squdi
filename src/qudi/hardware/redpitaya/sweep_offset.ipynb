# %%
"sds"
# Out:
# 'sds'

# %%
"""import redpitaya_pyrpl  # or adjust import to your path


PyRPL = redpitaya_pyrpl.RedPitayaPyrpl(qudi_main_weakref=None, name='PyRPL')

# Set config options explicitly
PyRPL._config_file = 'C:/Users/yy3/pyrpl_user_dir/config/test.yml'

PyRPL.on_activate()


PyRPL._asg1.setup(frequency=2e3, amplitude=0.3, start_phase=90, waveform='halframp', trigger_source='immediately')
PyRPL.on_deactivate()"""
# Out:
# "import redpitaya_pyrpl  # or adjust import to your path\n\n\nPyRPL = redpitaya_pyrpl.RedPitayaPyrpl(qudi_main_weakref=None, name='PyRPL')\n\n# Set config options explicitly\nPyRPL._config_file = 'C:/Users/yy3/pyrpl_user_dir/config/test.yml'\n\nPyRPL.on_activate()\n\n\nPyRPL._asg1.setup(frequency=2e3, amplitude=0.3, start_phase=90, waveform='halframp', trigger_source='immediately')\nPyRPL.on_deactivate()"

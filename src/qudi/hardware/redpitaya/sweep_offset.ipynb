# %%
from redpitaya_pyrpl import RedPitayaPyrpl  # or adjust import to your path
import time 

PyRPL = RedPitayaPyrpl(qudi_main_weakref=None, name='PyRPL')

# Set config options explicitly
PyRPL._config_file = 'C:/Users/yy3/pyrpl_user_dir/config/test.yml'

PyRPL.on_activate()


PyRPL._asg1.setup(frequency=2e3, amplitude=0.3, start_phase=90, waveform='halframp', trigger_source='immediately')
time.sleep(0.5)
PyRPL.on_deactivate()
# Out:
# No ConfigOption "config_file" configured, using default value "None" instead.
# y
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 10
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 12
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 14
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 16
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 18
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 20
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 22
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 24
# Error occured in reading attempt 0. Reconnecting at addr 0x40100014 to _reads value 1 by client 26
# ...

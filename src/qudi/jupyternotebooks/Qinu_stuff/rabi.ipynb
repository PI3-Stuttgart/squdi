# %%
AO_OPX.stop_rabi()

# %%
import time

# %%
import time
while True:
    ple_gui.toggle_optimize(True)
    print('run refocus')
    time.sleep(6)
    print('run rabi')
    AO_OPX.run_arb_puls(10, 
                    "square",
                    res_power=-0.16,
                    ppg_pulse_delay=5, 
                    wait_between_pulses=500,
                    AOM_end_buffer=0, 
                    pulse_amplitude=255,
                    vccrf=12000,
                    vref=250,
                    green_power=0
                    )
    time.sleep(3)
    print('stop rabi')
    AO_OPX.stop_curr_pulses()
    time.sleep(0.2)
    print('520 on')
    digital_switch_opx.set_state('Laser_520', 'on')
    time.sleep(1)
    print('520 off')
    digital_switch_opx.set_state('Laser_520', 'off')
# Out:
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import time



print('520 on')
digital_switch_opx.set_state('Laser_520', 'on')
time.sleep(1)
print('520 off')
digital_switch_opx.set_state('Laser_520', 'off')

for i in range(10):
    ple_gui.toggle_optimize(True)
    print('run refocus')
    time.sleep(6)
    print(f'Run rabi: {i}')
    AO_OPX.run_arb_puls(0.5, 
                    "gaussian",
                    res_power=-0.18,
                    ppg_pulse_delay=17, 
                    wait_between_pulses=500,
                    AOM_end_buffer=0,
                    pulse_amplitude=255,
                    vccrf=12000,
                    vref=250,
                    green_power=0
                    )
    time.sleep(5)
    print('stop rabi')
    AO_OPX.stop_curr_pulses()
    time.sleep(0.2)
    print('520 on')
    digital_switch_opx.set_state('Laser_520', 'on')
    time.sleep(1)
    print('520 off')
    digital_switch_opx.set_state('Laser_520', 'off')
# Out:
# 520 on
# 520 off
# run refocus
# Run rabi: 0
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 1
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 2
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 3
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 4
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 5
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 6
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 7
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 8
# stop rabi
# 520 on
# 520 off
# run refocus
# Run rabi: 9
# stop rabi
# 520 on
# 520 off

# %%
AO_OPX.run_arb_puls(0.5, 
                "gaussian",
                res_power=-0.16,
                ppg_pulse_delay=17, 
                wait_between_pulses=500,
                AOM_end_buffer=0,
                pulse_amplitude=255,
                vccrf=12000,
                vref=250,
                green_power=0
                )

# %%
AO_OPX.stop_curr_pulses()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
queuelogic._dlc_pro_620.set_pc_voltage(50)
# Out:
# 0

# %%
cfg["controllers"]["con1"]["analog_outputs"][4]["offset"] = 0.12

# %%
AO_OPX._opx.qm.update_config(cfg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 AO_OPX._opx.qm.update_config(cfg)
#
# File ~\anaconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:152, in BaseNetref.__getattr__(self, name)
#     150 if name in DELETED_ATTRS:
#     151     raise AttributeError()
# --> 152 return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File ~\anaconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      51 """Performs a synchronous request on the given proxy object.
#      52 Not intended to be invoked directly.
#      53
#    (...)
#      60 :returns: the result of the operation
#      61 """
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# ...

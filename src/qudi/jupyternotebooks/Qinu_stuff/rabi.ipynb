# %%
AO_OPX.stop_rabi()

# %%
import time

# %%
import time
while True:
    ple_gui.toggle_optimize(True)
    print('run refocus')
    time.sleep(6)
    print('run rabi')
    AO_OPX.run_arb_puls(10, 
                    "square",
                    res_power=-0.16,
                    ppg_pulse_delay=5, 
                    wait_between_pulses=500,
                    AOM_end_buffer=0, 
                    pulse_amplitude=255,
                    vccrf=12000,
                    vref=250,
                    green_power=0
                    )
    time.sleep(2)
    print('stop rabi')
    AO_OPX.stop_curr_pulses()
    time.sleep(0.2)
    print('520 on')
    digital_switch_opx.set_state('Laser_520', 'on')
    time.sleep(1)
    print('520 off')
    digital_switch_opx.set_state('Laser_520', 'off')
# Out:
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import time



print('520 on')
digital_switch_opx.set_state('Laser_520', 'on')
time.sleep(1)
print('520 off')
digital_switch_opx.set_state('Laser_520', 'off')

for i in range(10):
    ple_gui.toggle_optimize(True)
    print('run refocus')
    time.sleep(6)
    print(f'Run rabi: {i}')
    AO_OPX.run_arb_puls(0.5, 
                    "gaussian",
                    res_power=-0.16,
                    ppg_pulse_delay=17, 
                    wait_between_pulses=500,
                    AOM_end_buffer=0,
                    pulse_amplitude=255,
                    vccrf=12000,
                    vref=250,
                    green_power=0
                    )
    time.sleep(5)
    print('stop rabi')
    AO_OPX.stop_curr_pulses()
    time.sleep(0.2)
    print('520 on')
    digital_switch_opx.set_state('Laser_520', 'on')
    time.sleep(1)
    print('520 off')
    digital_switch_opx.set_state('Laser_520', 'off')
# Out:
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off
# run refocus
# run rabi
# stop rabi
# 520 on
# 520 off

# %%
AO_OPX.run_arb_puls(0.5, 
                "gaussian",
                res_power=-0.2,
                ppg_pulse_delay=17, 
                wait_between_pulses=500,
                AOM_end_buffer=0,
                pulse_amplitude=255,
                vccrf=12000,
                vref=250,
                green_power=0
                )

# %%
AO_OPX.stop_curr_pulses()

# %%
cfg = AO_OPX._opx.qm.get_config()

# %%
cfg
# Out:
# {'version': 1, 'controllers': {'con1': {'type': 'opx1', 'analog_outputs': {1: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 2: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 3: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 4: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 6: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 7: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 8: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 9: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}, 10: {'offset': 0.0, 'delay': 0, 'shareable': False, 'filter': {'feedforward': [], 'feedback': []}, 'crosstalk': {}}}, 'analog_inputs': {1: {'offset': 0.0, 'gain_db': -3, 'shareable': False}, 2: {'offset': 0.0, 'gain_db': -3, 'shareable': False}}, 'digital_outputs': {1: {'shareable': False, 'inverted': False}, 2: {'shareable': False, 'inverted': False}, 3: {'shareable': False, 'inverted': False}, 4: {'shareable': False, 'inverted': False}, 5: {'shareable': False, 'inverted': False}, 6: {'shareable': False, 'inverted': False}, 7: {'shareable': False, 'inverted': False}, 8: {'shareable': False, 'inverted': False}, 9: {'shareable': False, 'inverted': False}, 10: {'shareable': False, 'inverted': False}}, 'digital_inputs': {}}}, 'oscillators': {}, 'elements': {'Laser_450': {'digitalInputs': {'marker': {'delay': 0, 'buffer': 0, 'port': ('con1', 7)}}, 'digitalOutputs': {}, 'outputs': {}, 'operations': {'active': 'laser_ON'}, 'hold_offset': {'duration': 0}, 'sticky': {'analog': False, 'digital': False, 'duration': 4}, 'thread': ''}, 'Laser_520': {'digitalInputs': {'Laser': {'delay': 120, 'buffer': 0, 'port': ('con1', 6)}, 'AOM': {'delay': 120, 'buffer': 0, 'port': ('con1', 8)}}, 'digitalOutputs': {}, 'outputs': {}, 'operations': {'power': 'AOM_power', 'active': 'AOM_TTL', 'pulse': 'AOM_pulse'}, 'hold_offset': {'duration': 0}, 'sticky': {'analog': False, 'digital': False, 'duration': 4}, 'thread': '', 'singleInput': {'port': ('con1', 8)}}, 'Memory_Trigger': {'digitalInputs': {'trigger': {'delay': 600, 'buffer': 0, 'port': ('con1', 4)}}, 'digitalOutputs': {}, 'outputs': {}, 'operations': {'trigit': 'laser_ON'}, 'hold_offset': {'duration': 0}, 'sticky': {'analog': False, 'digital': False, 'duration': 4}, 'thread': ''}, 'NV': {'digitalInputs': {'switch': {'delay': 113, 'buffer': 25, 'port': ('con1', 1)}}, 'digitalOutputs': {}, 'outputs': {}, 'operations': {'cw': 'const_pulse', 'x180': 'x180_pulse', 'x90': 'x90_pulse', '-x90': '-x90_pulse', '-y90': '-y90_pulse', 'y90': 'y90_pulse', 'y180': 'y180_pulse'}, 'hold_offset': {'duration': 0}, 'sticky': {'analog': False, 'digital': False, 'duration': 4}, 'thread': '', 'mixInputs': {'I': ('con1', 1), 'Q': ('con1', 2), 'mixer': 'mixer_NV', 'lo_frequency': 2870000000.0}, 'intermediate_frequency': 108218000.0}, 'Gate_Trigger': {'digitalInputs': {'trigger': {'delay': 600, 'buffer': 0, 'port': ('con1', 3)}}, 'digitalOutputs': {}, 'outputs': {}, 'operations': {'trigit': 'laser_ON'}, 'hold_offset': {'duration': 0}, 'sticky': {'analog': False, 'digital': False, 'duration': 4}, 'thread': ''}, '620_pi_w_power': {'digitalInputs': {'ppg': {'delay': 382, 'buffer': 0, 'port': ('con1', 5)}, 'AOM_620_pi': {'delay': 110, 'buffer': 0, 'port': ('con1', 10)}}, 'digitalOutputs': {}, 'outputs': {}, 'operations': {'power': 'AOM_power', 'active': 'AOM_TTL', 'pulse': 'AOM_pulse'}, 'hold_offset': {'duration': 0}, 'sticky': {'analog': False, 'digital': False, 'duration': 4}, 'thread': '', 'singleInput': {'port': ('con1', 7)}}, 'LaserScanner_r ...

# %%
cfg["controllers"]["con1"]["analog_outputs"][4]["offset"] = 0.12

# %%
AO_OPX._opx.qm.update_config(cfg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 AO_OPX._opx.qm.update_config(cfg)
#
# File ~\anaconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:152, in BaseNetref.__getattr__(self, name)
#     150 if name in DELETED_ATTRS:
#     151     raise AttributeError()
# --> 152 return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File ~\anaconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      51 """Performs a synchronous request on the given proxy object.
#      52 Not intended to be invoked directly.
#      53
#    (...)
#      60 :returns: the result of the operation
#      61 """
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File ~\anaconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py:744, in Connection.sync_request(self, handler, *args)
#     741 _async_res = self.async_request(handler, *args, timeout=timeout)
#     742 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     743 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
# --> 744 return _async_res.value
#
# File ~\anaconda3\envs\squdi\lib\site-packages\rpyc\core\async_.py:111, in AsyncResult.value(self)
#     109 self.wait()
#     110 if self._is_exc:
# --> 111     raise self._obj
#     112 else:
#     113     return self._obj
#
# AttributeError: 'QuantumMachine' object has no attribute 'update_config'
#
# ========= Remote Traceback (1) =========
# Traceback (most recent call last):
#   File "C:\Users\yy3\anaconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py", line 369, in _dispatch_request
#     res = self._HANDLERS[handler](self, *args)
#   File "C:\Users\yy3\anaconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py", line 879, in _handle_getattr
#     return self._access_attr(obj, name, (), "_rpyc_getattr", "allow_getattr", getattr)
#   File "C:\Users\yy3\anaconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py", line 807, in _access_attr
#     return accessor(obj, name, *args)
# AttributeError: 'QuantumMachine' object has no attribute 'update_config'

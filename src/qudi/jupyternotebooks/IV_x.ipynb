# %%
import keithley2600
import numpy as np
from matplotlib import pyplot as plt
import time

# %%
smu = keithley2600.SMU26xx("USB0::0x05E6::0x2636::4365643::INSTR")

# %%
smu.get_available_voltage_ranges()
# Out:
# [0.2, 2, 20, 200]

# %%
smu.disconnect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 smu.disconnect()
#
# NameError: name 'smu' is not defined

# %%
smu._measure(smu.CHANNEL_ALL, smu.UNIT_CURRENT)
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 smu._measure(smu.CHANNEL_ALL, smu.UNIT_CURRENT)
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:980, in SMU26xx._measure(self, channel, unit)
#     977 else:
#     978     cmd = 'print(smu' + str(channel) + '.measure.' + str(unit) + '())'
# --> 980 reading = self.query_lua(cmd)
#     981 reading = reading.replace("'", "")
#     982 # if we get more than one value out then put it in a list
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:668, in SMU26xx.query_lua(self, cmd, check_for_errors)
#     666     print('Query cmd: ' + str(cmd))
#     667 # send the request to the device
# --> 668 reading = self.__instrument.query(str(cmd)).rstrip('\r\n')
#     669 if self.__debug:
#     670     print('Query answer: ' + str(reading))
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:647, in MessageBasedResource.query(self, message, delay)
#     644 if delay > 0.0:
#     645     time.sleep(delay)
# --> 647 return self.read()
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:485, in MessageBasedResource.read(self, termination, encoding)
#     483 if termination is None:
#     484     termination = self._read_termination
# --> 485     message = self._read_raw().decode(enco)
#     486 else:
#     487     with self.read_termination_context(termination):
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:441, in MessageBasedResource._read_raw(self, size)
#     434     while status == loop_status:
#     435         logger.debug(
#     436             "%s - reading %d bytes (last status %r)",
#     437             self._resource_name,
#     438             size,
#     439             status,
#     440         )
# --> 441         chunk, status = self.visalib.read(self.session, size)
#     442         ret.extend(chunk)
#     443 except errors.VisaIOError as e:
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\functions.py:2336, in read(library, session, count)
#    2334 buffer = create_string_buffer(count)
#    2335 return_count = ViUInt32()
# -> 2336 ret = library.viRead(session, buffer, count, byref(return_count))
#    2337 return buffer.raw[: return_count.value], ret
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\highlevel.py:226, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     223         # Set session back to a safe value
#     224         session = None
# --> 226 return self.handle_return_value(session, ret_value)
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
smu_a = smu.get_channel('a')

# %%
smu_a = smu.get_channel('a')

# %%
smu_a.set_voltage(0)

# %%
smu._measure('a', 'i') #smu.UNIT_CURRENT)
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 smu._measure('a', 'i') #smu.UNIT_CURRENT)
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:980, in SMU26xx._measure(self, channel, unit)
#     977 else:
#     978     cmd = 'print(smu' + str(channel) + '.measure.' + str(unit) + '())'
# --> 980 reading = self.query_lua(cmd)
#     981 reading = reading.replace("'", "")
#     982 # if we get more than one value out then put it in a list
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:668, in SMU26xx.query_lua(self, cmd, check_for_errors)
#     666     print('Query cmd: ' + str(cmd))
#     667 # send the request to the device
# --> 668 reading = self.__instrument.query(str(cmd)).rstrip('\r\n')
#     669 if self.__debug:
#     670     print('Query answer: ' + str(reading))
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:647, in MessageBasedResource.query(self, message, delay)
#     644 if delay > 0.0:
#     645     time.sleep(delay)
# --> 647 return self.read()
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:485, in MessageBasedResource.read(self, termination, encoding)
#     483 if termination is None:
#     484     termination = self._read_termination
# --> 485     message = self._read_raw().decode(enco)
#     486 else:
#     487     with self.read_termination_context(termination):
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:441, in MessageBasedResource._read_raw(self, size)
#     434     while status == loop_status:
#     435         logger.debug(
#     436             "%s - reading %d bytes (last status %r)",
#     437             self._resource_name,
#     438             size,
#     439             status,
#     440         )
# --> 441         chunk, status = self.visalib.read(self.session, size)
#     442         ret.extend(chunk)
#     443 except errors.VisaIOError as e:
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\functions.py:2336, in read(library, session, count)
#    2334 buffer = create_string_buffer(count)
#    2335 return_count = ViUInt32()
# -> 2336 ret = library.viRead(session, buffer, count, byref(return_count))
#    2337 return buffer.raw[: return_count.value], ret
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\highlevel.py:226, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     223         # Set session back to a safe value
#     224         session = None
# --> 226 return self.handle_return_value(session, ret_value)
#
# File ~\anaconda3\envs\squdi\lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
smu_a.set_voltage(0)

# %%
smu_a.set_voltage(-100)

# %%
smu_a.enable_output()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:630, in SMU26xx.__check_error_queue(self)
#     629 try:
# --> 630     [code, message] = response.split('\t', 1)
#     631     if float(code) != 0:
#     632         # if we have an error code something happened and we should raise an error
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 smu_a.enable_output()
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:259, in _SMUChannel.enable_output(self)
#     247 def enable_output(self):
#     248     """
#     249     Sets the source output state to on.
#     250
#    (...)
#     257        set_mode_voltage_source() or set_mode_current_source()
#     258     """
# --> 259     self.__smu._set_output_state(self.__channel, SMU26xx.STATE_ON)
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:948, in SMU26xx._set_output_state(self, channel, state)
#     946 def _set_output_state(self, channel, state):
#     947     cmd = 'smu' + str(channel) + '.source.output = smu' + str(channel) + '.OUTPUT_' + str(state)
# --> 948     self.write_lua(cmd)
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:652, in SMU26xx.write_lua(self, cmd, check_for_errors)
#     650 # check if the command executed without any errors
#     651 if check_for_errors:
# --> 652     self.__check_error_queue()
#
# File c:\Users\YY3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:635, in SMU26xx.__check_error_queue(self)
#     633         raise ValueError('The SMU said: "' + str(message) + '"  /  Keithley-Error-Code: ' + str(code))
#     634 except:
# --> 635     raise ValueError('The SMU said: "' + str(response))
#
# ValueError: The SMU said: "1.24856e-11

# %%
smu_a.enable_output()

# %%
def set_voltage(v):
    a = None
    for it in range(8):
        if a is None:
            try:
                time.sleep(0.5)
                smu_a.set_voltage(v)
                a = 1
            except:
                time.sleep(1)
                a = None
        else:
            break
    return 1

def get_current(current_v = None):
    i = None
    for it in range(8):
        if i is None:
            try:
                time.sleep(0.25)
                i = smu._measure('a', 'i') #smu.UNIT_CURRENT)
                
            except:
                time.sleep(1)
                i = None
                if current_v:
                    set_voltage(current_v)
                    time.sleep(0.5)
        else:
            break
    return i

# %%
set_voltage(0)
# Out:
# 1

# %%
get_current(current_v=0)
# Out:
# 1.39189e-11

# %%
volts = np.linspace(-130, 130, 5)
Is = []

for v in volts:
    time.sleep(0.25)
    set_voltage(v)
    
    i = get_current(current_v=v)
    time.sleep(0.25)
    Is.append(i)
Is_forward = Is

Is = []

for v in volts[::-1]:
    time.sleep(0.25)
    set_voltage(v)
    
    i = get_current(current_v=v)
    time.sleep(0.25)
    Is.append(i)

Is_backwards = Is

# %%
Is = []
Vs = []

# %%
volts = list(np.linspace(-130, 130, 150))

# %%
for v in volts:
    for it in range(15):
        a = 0
        try:
            smu_a.set_voltage(v)
            a = 1
        except:
            print("Ups")
        if a == 1:
            print("VDone")
            break
        time.sleep(1 + 0.5*it)

    for it in range(15):
        i = None
        try:
            i = smu._measure('a', 'i') #smu.UNIT_CURRENT)
        except:
            print("Ups I")
        time.sleep(0.25)
        if i is not None:
            Is.append(i)
            Vs.append(v)
            print('Done', i, v)
            break
        time.sleep(1 + 0.5*it)
# Out:
# Ups
# VDone
# Done 2.16587e-10 -130.0
# Ups
# VDone
# Ups I
# Done 2.39782e-10 -128.25503355704697
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -4.01734e-10 -126.51006711409396
# Ups
# VDone
# Done -4.04079e-10 -124.76510067114094
# Ups
# VDone
# Done -4.06441e-10 -123.02013422818791
# Ups
# VDone
# Ups I
# Done -4.01512e-10 -121.2751677852349
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.94427e-10 -119.53020134228188
# Ups
# VDone
# Done -3.95474e-10 -117.78523489932886
# Ups
# VDone
# Done -3.93267e-10 -116.04026845637584
# Ups
# VDone
# Ups I
# Done -3.87442e-10 -114.29530201342283
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.86157e-10 -112.5503355704698
# Ups
# VDone
# Done -3.81125e-10 -110.80536912751678
# Ups
# VDone
# Done -3.82904e-10 -109.06040268456375
# Ups
# VDone
# Ups I
# Done -3.81228e-10 -107.31543624161074
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.72493e-10 -105.57046979865771
# Ups
# VDone
# Done -3.76977e-10 -103.8255033557047
# Ups
# VDone
# Done -3.81401e-10 -102.08053691275168
# Ups
# VDone
# Ups I
# Done -3.73447e-10 -100.33557046979865
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.58007e-10 -98.59060402684564
# Ups
# VDone
# Done -3.58041e-10 -96.84563758389262
# Ups
# VDone
# Done -3.51819e-10 -95.1006711409396
# Ups
# VDone
# Ups I
# Done -3.47729e-10 -93.35570469798658
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.32993e-10 -91.61073825503357
# Ups
# VDone
# Done -3.33321e-10 -89.86577181208054
# Ups
# VDone
# Done -3.33217e-10 -88.12080536912751
# Ups
# VDone
# Ups I
# Done -3.30319e-10 -86.3758389261745
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.16375e-10 -84.63087248322148
# Ups
# VDone
# Done -3.1626e-10 -82.88590604026845
# Ups
# VDone
# Done -3.13565e-10 -81.14093959731544
# Ups
# VDone
# Ups I
# Done -3.09099e-10 -79.39597315436242
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -2.90037e-10 -77.6510067114094
# Ups
# VDone
# Done -2.88194e-10 -75.90604026845638
# Ups
# VDone
# Done -2.88119e-10 -74.16107382550337
# Ups
# VDone
# Ups I
# Done -2.78156e-10 -72.41610738255034
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -2.44353e-10 -70.67114093959731
# Ups
# VDone
# Done -2.43497e-10 -68.92617449664431
# Ups
# VDone
# Done -2.43309e-10 -67.18120805369128
# Ups
# VDone
# Ups I
# Done -2.26061e-10 -65.43624161073826
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.64647e-10 -63.691275167785236
# Ups
# VDone
# Done -1.64801e-10 -61.94630872483222
# Ups
# VDone
# Done -1.64782e-10 -60.20134228187919
# Ups
# VDone
# Ups I
# Done -1.42434e-10 -58.45637583892618
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.04466e-10 -56.71140939597316
# Ups
# VDone
# Done -1.05626e-10 -54.966442953020135
# Ups
# VDone
# Done -1.06319e-10 -53.22147651006712
# Ups
# VDone
# Ups I
# Done -1.00436e-10 -51.47651006711409
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -8.96631e-11 -49.73154362416108
# Ups
# VDone
# Done -9.40987e-11 -47.98657718120806
# Ups
# VDone
# Done -9.64003e-11 -46.241610738255034
# Ups
# VDone
# Ups I
# Done -9.1215e-11 -44.49664429530202
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -7.71166e-11 -42.75167785234899
# Ups
# VDone
# Done -8.47726e-11 -41.006711409395976
# Ups
# VDone
# Done -8.83617e-11 -39.26174496644296
# Ups
# VDone
# Ups I
# Done -8.25609e-11 -37.51677852348993
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -5.93949e-11 -35.77181208053692
# Ups
# VDone
# Done -7.26484e-11 -34.026845637583904
# Ups
# VDone
# Done -7.85574e-11 -32.281879194630875
# Ups
# VDone
# Ups I
# Done -6.94837e-11 -30.53691275167786
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -2.32216e-11 -28.79194630872483
# Ups
# VDone
# Done -5.41634e-11 -27.046979865771817
# Ups
# VDone
# Done -6.33658e-11 -25.302013422818803
# Ups
# VDone
# Ups I
# Done -4.46664e-11 -23.557046979865774
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.59655e-11 -21.81208053691276
# Ups
# VDone
# Done -2.37848e-11 -20.06711409395973
# Ups
# VDone
# Done -4.22836e-11 -18.322147651006716
# Ups
# VDone
# Ups I
# Done -5.50137e-12 -16.5771812080537
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.70948e-11 -14.832214765100673
# Ups
# VDone
# Done 9.46095e-12 -13.087248322147659
# Ups
# VDone
# Done -1.42971e-11 -11.34228187919463
# Ups
# VDone
# Ups I
# Done 2.44819e-11 -9.597315436241615
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 6.11466e-11 -7.852348993288601
# Ups
# VDone
# Done 4.5746e-11 -6.107382550335572
# Ups
# VDone
# Done 3.04976e-11 -4.362416107382558
# Ups
# VDone
# Ups I
# Done 5.2306e-11 -2.617449664429529
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 7.55491e-11 -0.8724832214765286
# Ups
# VDone
# Done 6.59574e-11 0.8724832214765001
# Ups
# VDone
# Done 5.74902e-11 2.617449664429529
# Ups
# VDone
# Ups I
# Done 6.91841e-11 4.362416107382558
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 9.76291e-11 6.107382550335558
# Ups
# VDone
# Done 9.79802e-11 7.852348993288587
# Ups
# VDone
# Done 9.23001e-11 9.597315436241615
# Ups
# VDone
# Ups I
# Done 9.97589e-11 11.342281879194616
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 9.06912e-11 13.087248322147644
# Ups
# VDone
# Done 8.68775e-11 14.832214765100673
# Ups
# VDone
# Done 8.34035e-11 16.577181208053673
# Ups
# VDone
# Ups I
# Done 8.97786e-11 18.322147651006702
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 9.86315e-11 20.06711409395973
# Ups
# VDone
# Done 9.45275e-11 21.81208053691273
# Ups
# VDone
# Done 9.22274e-11 23.55704697986576
# Ups
# VDone
# Ups I
# Done 9.70713e-11 25.30201342281879
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.05847e-10 27.046979865771817
# Ups
# VDone
# Done 1.02614e-10 28.791946308724818
# Ups
# VDone
# Done 9.84504e-11 30.536912751677846
# Ups
# VDone
# Ups I
# Done 1.00619e-10 32.281879194630875
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.10579e-10 34.026845637583875
# Ups
# VDone
# Done 1.06784e-10 35.771812080536904
# Ups
# VDone
# Done 1.03948e-10 37.51677852348993
# Ups
# VDone
# Ups I
# Done 1.0678e-10 39.26174496644293
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.13991e-10 41.00671140939596
# Ups
# VDone
# Done 1.11183e-10 42.75167785234899
# Ups
# VDone
# Done 1.08901e-10 44.49664429530202
# Ups
# VDone
# Ups I
# Done 1.10884e-10 46.24161073825502
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.18385e-10 47.98657718120805
# Ups
# VDone
# Done 1.1575e-10 49.73154362416108
# Ups
# VDone
# Done 1.12841e-10 51.47651006711408
# Ups
# VDone
# Ups I
# Done 1.16043e-10 53.221476510067106
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.30432e-10 54.966442953020135
# Ups
# VDone
# Done 1.26446e-10 56.711409395973135
# Ups
# VDone
# Done 1.25598e-10 58.456375838926164
# Ups
# VDone
# Ups I
# Done 1.31793e-10 60.20134228187919
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.63036e-10 61.94630872483219
# Ups
# VDone
# Done 1.64643e-10 63.69127516778522
# Ups
# VDone
# Done 1.58149e-10 65.43624161073825
# Ups
# VDone
# Ups I
# Done 1.71685e-10 67.18120805369128
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.09352e-10 68.92617449664428
# Ups
# VDone
# Done 2.06693e-10 70.67114093959731
# Ups
# VDone
# Done 2.11779e-10 72.41610738255034
# Ups
# VDone
# Ups I
# Done 2.16109e-10 74.16107382550334
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.41585e-10 75.90604026845637
# Ups
# VDone
# Done 2.43607e-10 77.6510067114094
# Ups
# VDone
# Done 2.45151e-10 79.3959731543624
# Ups
# VDone
# Ups I
# Done 2.5097e-10 81.14093959731542
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.63686e-10 82.88590604026845
# Ups
# VDone
# Done 2.61787e-10 84.63087248322148
# Ups
# VDone
# Done 2.68974e-10 86.37583892617448
# Ups
# VDone
# Ups I
# Done 2.76697e-10 88.12080536912751
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.97312e-10 89.86577181208054
# Ups
# VDone
# Done 3.00229e-10 91.61073825503354
# Ups
# VDone
# Done 3.02738e-10 93.35570469798657
# Ups
# VDone
# Ups I
# Done 3.05931e-10 95.1006711409396
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.5358e-10 96.8456375838926
# Ups
# VDone
# Done 3.45601e-10 98.59060402684563
# Ups
# VDone
# Done 3.4987e-10 100.33557046979865
# Ups
# VDone
# Ups I
# Done 3.73513e-10 102.08053691275165
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.62987e-10 103.82550335570468
# Ups
# VDone
# Done 3.6319e-10 105.57046979865771
# Ups
# VDone
# Done 3.75603e-10 107.31543624161074
# Ups
# VDone
# Ups I
# Done 3.88531e-10 109.06040268456374
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.60226e-10 110.80536912751677
# Ups
# VDone
# Done 3.40295e-10 112.5503355704698
# Ups
# VDone
# Done 3.28867e-10 114.2953020134228
# Ups
# VDone
# Ups I
# Done 3.30493e-10 116.04026845637583
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.33668e-10 117.78523489932886
# Ups
# VDone
# Done 3.31267e-10 119.53020134228186
# Ups
# VDone
# Done 3.31154e-10 121.27516778523488
# Ups
# VDone
# Ups I
# Done 3.30903e-10 123.02013422818791
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.41857e-10 124.76510067114094
# Ups
# VDone
# Done 3.3974e-10 126.51006711409394
# Ups
# VDone
# Done 3.37756e-10 128.25503355704694
# Ups
# VDone
# Ups I
# Done 3.41916e-10 130.0

# %%
Is0 = Is
Vs0 = Vs

# %%
plt.plot(Vs, Is)

# %%
Is_green = []
Vs_green = []

# %%
ibeam_smart.power = 30e3

# %%
for v in volts:
    for it in range(15):
        a = 0
        try:
            smu_a.set_voltage(v)
            a = 1
        except:
            print("Ups")
        if a == 1:
            print("VDone")
            break
        time.sleep(1 + 0.5*it)

    for it in range(15):
        i = None
        try:
            i = smu._measure('a', 'i') #smu.UNIT_CURRENT)
        except:
            print("Ups I")
        time.sleep(0.25)
        if i is not None:
            Is_green.append(i)
            Vs_green.append(v)
            print('Done', i, v)
            break
        time.sleep(1 + 0.5*it)
# Out:
# Ups
# VDone
# Done 3.45493e-10 -130.0
# Ups
# VDone
# Ups I
# Done 3.48328e-10 -128.25503355704697
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.51736e-10 -126.51006711409396
# Ups
# VDone
# Done -3.60581e-10 -124.76510067114094
# Ups
# VDone
# Done -3.57483e-10 -123.02013422818791
# Ups
# VDone
# Ups I
# Done -3.74388e-10 -121.2751677852349
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.54022e-10 -119.53020134228188
# Ups
# VDone
# Done -3.56074e-10 -117.78523489932886
# Ups
# VDone
# Done -3.62365e-10 -116.04026845637584
# Ups
# VDone
# Ups I
# Done -3.70424e-10 -114.29530201342283
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.54885e-10 -112.5503355704698
# Ups
# VDone
# Done -3.64011e-10 -110.80536912751678
# Ups
# VDone
# Done -3.536e-10 -109.06040268456375
# Ups
# VDone
# Ups I
# Done -3.70327e-10 -107.31543624161074
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.50432e-10 -105.57046979865771
# Ups
# VDone
# Done -3.53205e-10 -103.8255033557047
# Ups
# VDone
# Done -3.49167e-10 -102.08053691275168
# Ups
# VDone
# Ups I
# Done -3.50071e-10 -100.33557046979865
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.32244e-10 -98.59060402684564
# Ups
# VDone
# Done -3.30861e-10 -96.84563758389262
# Ups
# VDone
# Done -3.21758e-10 -95.1006711409396
# Ups
# VDone
# Ups I
# Done -3.21182e-10 -93.35570469798658
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.08613e-10 -91.61073825503357
# Ups
# VDone
# Done -3.10263e-10 -89.86577181208054
# Ups
# VDone
# Done -2.99756e-10 -88.12080536912751
# Ups
# VDone
# Ups I
# Done -3.13724e-10 -86.3758389261745
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.36351e-10 -84.63087248322148
# Ups
# VDone
# Done -3.23465e-10 -82.88590604026845
# Ups
# VDone
# Done -3.17115e-10 -81.14093959731544
# Ups
# VDone
# Ups I
# Done -3.21025e-10 -79.39597315436242
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.17454e-10 -77.6510067114094
# Ups
# VDone
# Done -3.15734e-10 -75.90604026845638
# Ups
# VDone
# Done -3.34442e-10 -74.16107382550337
# Ups
# VDone
# Ups I
# Done -2.71037e-10 -72.41610738255034
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -2.4691e-10 -70.67114093959731
# Ups
# VDone
# Done -2.44745e-10 -68.92617449664431
# Ups
# VDone
# Done -2.43479e-10 -67.18120805369128
# Ups
# VDone
# Ups I
# Done -2.3672e-10 -65.43624161073826
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -2.21572e-10 -63.691275167785236
# Ups
# VDone
# Done -2.23441e-10 -61.94630872483222
# Ups
# VDone
# Done -2.231e-10 -60.20134228187919
# Ups
# VDone
# Ups I
# Done -2.189e-10 -58.45637583892618
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.90716e-10 -56.71140939597316
# Ups
# VDone
# Done -1.89013e-10 -54.966442953020135
# Ups
# VDone
# Done -1.90221e-10 -53.22147651006712
# Ups
# VDone
# Ups I
# Done -1.81731e-10 -51.47651006711409
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.54194e-10 -49.73154362416108
# Ups
# VDone
# Done -1.57324e-10 -47.98657718120806
# Ups
# VDone
# Done -1.55812e-10 -46.241610738255034
# Ups
# VDone
# Ups I
# Done -1.50815e-10 -44.49664429530202
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.38836e-10 -42.75167785234899
# Ups
# VDone
# Done -1.39281e-10 -41.006711409395976
# Ups
# VDone
# Done -1.41197e-10 -39.26174496644296
# Ups
# VDone
# Ups I
# Done -1.38609e-10 -37.51677852348993
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.33605e-10 -35.77181208053692
# Ups
# VDone
# Done -1.33896e-10 -34.026845637583904
# Ups
# VDone
# Done -1.34421e-10 -32.281879194630875
# Ups
# VDone
# Ups I
# Done -1.31145e-10 -30.53691275167786
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.24631e-10 -28.79194630872483
# Ups
# VDone
# Done -1.27689e-10 -27.046979865771817
# Ups
# VDone
# Done -1.27678e-10 -25.302013422818803
# Ups
# VDone
# Ups I
# Done -1.26401e-10 -23.557046979865774
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.16786e-10 -21.81208053691276
# Ups
# VDone
# Done -1.20888e-10 -20.06711409395973
# Ups
# VDone
# Done -1.21135e-10 -18.322147651006716
# Ups
# VDone
# Ups I
# Done -1.16858e-10 -16.5771812080537
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.01467e-10 -14.832214765100673
# Ups
# VDone
# Done -1.03631e-10 -13.087248322147659
# Ups
# VDone
# Done -1.03843e-10 -11.34228187919463
# Ups
# VDone
# Ups I
# Done -9.14259e-11 -9.597315436241615
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 4.7966e-11 -7.852348993288601
# Ups
# VDone
# Done 2.44296e-11 -6.107382550335572
# Ups
# VDone
# Done 6.90448e-12 -4.362416107382558
# Ups
# VDone
# Ups I
# Done 4.78773e-11 -2.617449664429529
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 7.59071e-11 -0.8724832214765286
# Ups
# VDone
# Done 6.66376e-11 0.8724832214765001
# Ups
# VDone
# Done 5.7242e-11 2.617449664429529
# Ups
# VDone
# Ups I
# Done 6.9588e-11 4.362416107382558
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 8.6743e-11 6.107382550335558
# Ups
# VDone
# Done 8.00515e-11 7.852348993288587
# Ups
# VDone
# Done 7.42211e-11 9.597315436241615
# Ups
# VDone
# Ups I
# Done 8.38027e-11 11.342281879194616
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 9.80033e-11 13.087248322147644
# Ups
# VDone
# Done 9.35096e-11 14.832214765100673
# Ups
# VDone
# Done 8.98007e-11 16.577181208053673
# Ups
# VDone
# Ups I
# Done 9.51664e-11 18.322147651006702
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.02594e-10 20.06711409395973
# Ups
# VDone
# Done 1.0129e-10 21.81208053691273
# Ups
# VDone
# Done 9.91746e-11 23.55704697986576
# Ups
# VDone
# Ups I
# Done 1.02391e-10 25.30201342281879
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.11689e-10 27.046979865771817
# Ups
# VDone
# Done 1.08578e-10 28.791946308724818
# Ups
# VDone
# Done 1.05683e-10 30.536912751677846
# Ups
# VDone
# Ups I
# Done 1.08701e-10 32.281879194630875
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.15612e-10 34.026845637583875
# Ups
# VDone
# Done 1.12799e-10 35.771812080536904
# Ups
# VDone
# Done 1.1121e-10 37.51677852348993
# Ups
# VDone
# Ups I
# Done 1.13038e-10 39.26174496644293
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.19649e-10 41.00671140939596
# Ups
# VDone
# Done 1.17065e-10 42.75167785234899
# Ups
# VDone
# Done 1.15642e-10 44.49664429530202
# Ups
# VDone
# Ups I
# Done 1.17949e-10 46.24161073825502
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.25452e-10 47.98657718120805
# Ups
# VDone
# Done 1.2359e-10 49.73154362416108
# Ups
# VDone
# Done 1.20803e-10 51.47651006711408
# Ups
# VDone
# Ups I
# Done 1.25182e-10 53.221476510067106
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.35001e-10 54.966442953020135
# Ups
# VDone
# Done 1.32821e-10 56.711409395973135
# Ups
# VDone
# Done 1.32325e-10 58.456375838926164
# Ups
# VDone
# Ups I
# Done 1.37838e-10 60.20134228187919
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.48646e-10 61.94630872483219
# Ups
# VDone
# Done 1.48312e-10 63.69127516778522
# Ups
# VDone
# Done 1.47397e-10 65.43624161073825
# Ups
# VDone
# Ups I
# Done 1.5108e-10 67.18120805369128
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.67393e-10 68.92617449664428
# Ups
# VDone
# Done 1.64581e-10 70.67114093959731
# Ups
# VDone
# Done 1.63378e-10 72.41610738255034
# Ups
# VDone
# Ups I
# Done 1.68198e-10 74.16107382550334
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 1.88559e-10 75.90604026845637
# Ups
# VDone
# Done 1.85005e-10 77.6510067114094
# Ups
# VDone
# Done 1.90094e-10 79.3959731543624
# Ups
# VDone
# Ups I
# Done 1.94978e-10 81.14093959731542
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.11767e-10 82.88590604026845
# Ups
# VDone
# Done 2.10112e-10 84.63087248322148
# Ups
# VDone
# Done 2.14634e-10 86.37583892617448
# Ups
# VDone
# Ups I
# Done 2.16701e-10 88.12080536912751
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.28825e-10 89.86577181208054
# Ups
# VDone
# Done 2.31859e-10 91.61073825503354
# Ups
# VDone
# Done 2.31272e-10 93.35570469798657
# Ups
# VDone
# Ups I
# Done 2.37766e-10 95.1006711409396
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.52021e-10 96.8456375838926
# Ups
# VDone
# Done 2.50544e-10 98.59060402684563
# Ups
# VDone
# Done 2.51549e-10 100.33557046979865
# Ups
# VDone
# Ups I
# Done 2.56999e-10 102.08053691275165
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 2.72376e-10 103.82550335570468
# Ups
# VDone
# Done 2.76626e-10 105.57046979865771
# Ups
# VDone
# Done 2.77862e-10 107.31543624161074
# Ups
# VDone
# Ups I
# Done 2.9096e-10 109.06040268456374
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.2236e-10 110.80536912751677
# Ups
# VDone
# Done 3.24817e-10 112.5503355704698
# Ups
# VDone
# Done 3.28827e-10 114.2953020134228
# Ups
# VDone
# Ups I
# Done 3.26776e-10 116.04026845637583
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.3901e-10 117.78523489932886
# Ups
# VDone
# Done 3.35944e-10 119.53020134228186
# Ups
# VDone
# Done 3.27938e-10 121.27516778523488
# Ups
# VDone
# Ups I
# Done 3.27123e-10 123.02013422818791
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done 3.41298e-10 124.76510067114094
# Ups
# VDone
# Done 3.38383e-10 126.51006711409394
# Ups
# VDone
# Done 3.38312e-10 128.25503355704694
# Ups
# VDone
# Ups I
# Done 3.37381e-10 130.0

# %%
plt.plot(Vs_green, Is_green, 'green')

# %%
Is_0 = []
Vs_0 = []
ibeam_smart.power = 0

# %%
for v in volts:
    for it in range(15):
        a = 0
        try:
            smu_a.set_voltage(v)
            a = 1
        except:
            print("Ups")
        if a == 1:
            print("VDone")
            break
        time.sleep(1 + 0.5*it)

    for it in range(15):
        i = None
        try:
            i = smu._measure('a', 'i') #smu.UNIT_CURRENT)
        except:
            print("Ups I")
        time.sleep(0.25)
        if i is not None:
            Is_0.append(i)
            Vs_0.append(v)
            print('Done', i, v)
            break
        time.sleep(1 + 0.5*it)
# Out:
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.91307e-10 -130.0
# Ups
# VDone
# Done -3.86521e-10 -128.25503355704697
# Ups
# VDone
# Done -3.72851e-10 -126.51006711409396
# Ups
# VDone
# Ups I
# Done -3.7784e-10 -124.76510067114094
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.61269e-10 -123.02013422818791
# Ups
# VDone
# Done -3.76021e-10 -121.2751677852349
# Ups
# VDone
# Done -3.85343e-10 -119.53020134228188
# Ups
# VDone
# Ups I
# Done -3.56988e-10 -117.78523489932886
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.47695e-10 -116.04026845637584
# Ups
# VDone
# Done -3.48296e-10 -114.29530201342283
# Ups
# VDone
# Done -3.72433e-10 -112.5503355704698
# Ups
# VDone
# Ups I
# Done -3.50514e-10 -110.80536912751678
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.49555e-10 -109.06040268456375
# Ups
# VDone
# Done -3.50737e-10 -107.31543624161074
# Ups
# VDone
# Done -3.71869e-10 -105.57046979865771
# Ups
# VDone
# Ups I
# Done -3.53163e-10 -103.8255033557047
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.41675e-10 -102.08053691275168
# Ups
# VDone
# Done -3.59148e-10 -100.33557046979865
# Ups
# VDone
# Done -3.49867e-10 -98.59060402684564
# Ups
# VDone
# Ups I
# Done -3.4926e-10 -96.84563758389262
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.24539e-10 -95.1006711409396
# Ups
# VDone
# Done -3.03681e-10 -93.35570469798658
# Ups
# VDone
# Done -3.17205e-10 -91.61073825503357
# Ups
# VDone
# Ups I
# Done -3.24601e-10 -89.86577181208054
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.08197e-10 -88.12080536912751
# Ups
# VDone
# Done -3.00692e-10 -86.3758389261745
# Ups
# VDone
# Done -3.42322e-10 -84.63087248322148
# Ups
# VDone
# Ups I
# Done -3.26604e-10 -82.88590604026845
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -3.02538e-10 -81.14093959731544
# Ups
# VDone
# Done -2.82932e-10 -79.39597315436242
# Ups
# VDone
# Done -3.05457e-10 -77.6510067114094
# Ups
# VDone
# Ups I
# Done -2.59903e-10 -75.90604026845638
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.14391e-10 -74.16107382550337
# Ups
# VDone
# Done -1.16545e-10 -72.41610738255034
# Ups
# VDone
# Done -1.17596e-10 -70.67114093959731
# Ups
# VDone
# Ups I
# Done -1.13358e-10 -68.92617449664431
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.06507e-10 -67.18120805369128
# Ups
# VDone
# Done -1.09039e-10 -65.43624161073826
# Ups
# VDone
# Done -1.11556e-10 -63.691275167785236
# Ups
# VDone
# Ups I
# Done -1.08669e-10 -61.94630872483222
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Done -1.00019e-10 -60.20134228187919
# Ups
# VDone
# Done -1.0427e-10 -58.45637583892618
# Ups
# VDone
# Done -1.06595e-10 -56.71140939597316
# Ups
# VDone
# Ups I
# Done -1.02332e-10 -54.966442953020135
# VDone
# Ups I
# Done -1.02539e-10 -53.22147651006712
# VDone
# Ups I
# Done -1.01416e-10 -51.47651006711409
# Ups
# VDone
# Ups I
# Done -9.94269e-11 -49.73154362416108
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -9.93756e-11 -46.241610738255034
# Ups
# VDone
# Done -9.97945e-11 -44.49664429530202
# Ups
# VDone
# Done -1.00503e-10 -42.75167785234899
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -9.43608e-11 -39.26174496644296
# Ups
# VDone
# Done -9.3971e-11 -37.51677852348993
# Ups
# VDone
# Done -9.45621e-11 -35.77181208053692
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -8.57532e-11 -32.281879194630875
# Ups
# VDone
# Done -8.6737e-11 -30.53691275167786
# Ups
# VDone
# Done -8.72906e-11 -28.79194630872483
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -7.59297e-11 -25.302013422818803
# Ups
# VDone
# Done -7.71143e-11 -23.557046979865774
# Ups
# VDone
# Done -7.71724e-11 -21.81208053691276
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -6.17104e-11 -18.322147651006716
# Ups
# VDone
# Done -6.35915e-11 -16.5771812080537
# Ups
# VDone
# Done -6.49595e-11 -14.832214765100673
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -4.54583e-11 -11.34228187919463
# Ups
# VDone
# Done -4.82772e-11 -9.597315436241615
# Ups
# VDone
# Done -4.98937e-11 -7.852348993288601
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.1379e-11 -4.362416107382558
# Ups
# VDone
# Done -1.56068e-11 -2.617449664429529
# Ups
# VDone
# Done -1.93482e-11 -0.8724832214765286
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 2.94753e-11 2.617449664429529
# Ups
# VDone
# Done 2.53182e-11 4.362416107382558
# Ups
# VDone
# Done 2.18702e-11 6.107382550335558
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 5.49302e-11 9.597315436241615
# Ups
# VDone
# Done 5.22955e-11 11.342281879194616
# Ups
# VDone
# Done 5.07129e-11 13.087248322147644
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 7.0175e-11 16.577181208053673
# Ups
# VDone
# Done 6.84897e-11 18.322147651006702
# Ups
# VDone
# Done 6.69327e-11 20.06711409395973
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 8.15655e-11 23.55704697986576
# Ups
# VDone
# Done 7.97015e-11 25.30201342281879
# Ups
# VDone
# Done 7.85917e-11 27.046979865771817
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 8.72119e-11 30.536912751677846
# Ups
# VDone
# Done 8.64262e-11 32.281879194630875
# Ups
# VDone
# Done 8.51352e-11 34.026845637583875
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 9.21834e-11 37.51677852348993
# Ups
# VDone
# Done 9.09274e-11 39.26174496644293
# Ups
# VDone
# Done 8.97976e-11 41.00671140939596
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 9.76105e-11 44.49664429530202
# Ups
# VDone
# Done 9.64248e-11 46.24161073825502
# Ups
# VDone
# Done 9.60742e-11 47.98657718120805
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.02063e-10 51.47651006711408
# Ups
# VDone
# Done 1.00878e-10 53.221476510067106
# Ups
# VDone
# Done 1.0228e-10 54.966442953020135
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.07572e-10 58.456375838926164
# Ups
# VDone
# Done 1.07295e-10 60.20134228187919
# Ups
# VDone
# Done 1.05608e-10 61.94630872483219
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.11107e-10 65.43624161073825
# Ups
# VDone
# Done 1.10959e-10 67.18120805369128
# Ups
# VDone
# Done 1.11501e-10 68.92617449664428
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.15336e-10 72.41610738255034
# Ups
# VDone
# Done 1.14801e-10 74.16107382550334
# Ups
# VDone
# Done 1.14534e-10 75.90604026845637
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.18999e-10 79.3959731543624
# Ups
# VDone
# Done 1.18927e-10 81.14093959731542
# Ups
# VDone
# Done 1.18835e-10 82.88590604026845
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.24643e-10 86.37583892617448
# Ups
# VDone
# Done 1.24264e-10 88.12080536912751
# Ups
# VDone
# Done 1.255e-10 89.86577181208054
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.71569e-10 93.35570469798657
# Ups
# VDone
# Done 1.91002e-10 95.1006711409396
# Ups
# VDone
# Done 1.818e-10 96.8456375838926
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.18599e-10 100.33557046979865
# Ups
# VDone
# Done 3.22638e-10 102.08053691275165
# Ups
# VDone
# Done 3.27729e-10 103.82550335570468
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.56367e-10 107.31543624161074
# Ups
# VDone
# Done 3.54048e-10 109.06040268456374
# Ups
# VDone
# Done 3.53678e-10 110.80536912751677
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.52226e-10 114.2953020134228
# Ups
# VDone
# Done 3.63603e-10 116.04026845637583
# Ups
# VDone
# Done 3.24894e-10 117.78523489932886
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.13235e-10 121.27516778523488
# Ups
# VDone
# Done 3.34064e-10 123.02013422818791
# Ups
# VDone
# Done 3.16745e-10 124.76510067114094
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.30126e-10 128.25503355704694
# Ups
# VDone
# Done 3.36775e-10 130.0

# %%
plt.plot(Vs0, Is0, 'black')

# %%
plt.plot(Vs0[-150:], Is0[-150:], 'black')
plt.plot(Vs_green, Is_green, 'green')

# %%
Is_blue = []
Vs_blue = []
ibeam_smart.power = 0

# %%
smu_a.set_voltage(0)

# %%
smu._measure('a', 'i') * 1e9
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 smu._measure('a', 'i') * 1e9
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:987, in SMU26xx._measure(self, channel, unit)
#     985 if len(parts) > 1:
#     986     for value in parts:
# --> 987         out.append(float(value))
#     988     return out
#     989 else:
#
# ValueError: could not convert string to float: 'Queue Is Empty'

# %%
smu._measure('a', 'i') * 1e9
# Out:
# 0.0111396

# %%
def set_voltage(v):    
    for it in range(15):
            a = 0
            try:
                smu_a.set_voltage(v)
                a = 1
            except:
                print("Ups")
            if a == 1:
                print("VDone")
                break
            time.sleep(1 + 0.1*it)

def measure_I():
    for it in range(15):
        i = None
        try:
            i = smu._measure('a', 'i') * 1e9 #smu.UNIT_CURRENT)
        except:
            print("Ups I")
        time.sleep(0.25)
        if i is not None:
            print('Done', i, v)
            break
        time.sleep(1 + 0.1*it)

# %%
set_voltage(200)
# Out:
# 1

# %%
set_voltage(0)
# Out:
# 1

# %%
set_voltage(0)
# Out:
# 1

# %%
set_voltage()

# %%
measure_I()
set_voltage(-25)
# Out:
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I

# %%
smu_a.enable_output()

# %%
for v in volts:
    for it in range(15):
        a = 0
        try:
            smu_a.set_voltage(v)
            a = 1
        except:
            print("Ups")
        if a == 1:
            print("VDone")
            break
        time.sleep(1 + 0.1*it)

    for it in range(15):
        i = None
        try:
            i = smu._measure('a', 'i') #smu.UNIT_CURRENT)
        except:
            print("Ups I")
        time.sleep(0.25)
        if i is not None:
            Is_blue.append(i)
            Vs_blue.append(v)
            print('Done', i, v)
            break
        time.sleep(1 + 0.1*it)
# Out:
# Ups
# VDone
# Done 3.3357e-10 -130.0
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.59533e-10 -126.51006711409396
# Ups
# VDone
# Done -3.63128e-10 -124.76510067114094
# Ups
# VDone
# Done -3.73584e-10 -123.02013422818791
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.58923e-10 -119.53020134228188
# Ups
# VDone
# Done -3.56377e-10 -117.78523489932886
# Ups
# VDone
# Done -3.49326e-10 -116.04026845637584
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.53681e-10 -112.5503355704698
# Ups
# VDone
# Done -3.58559e-10 -110.80536912751678
# Ups
# VDone
# Done -3.63838e-10 -109.06040268456375
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.55802e-10 -105.57046979865771
# Ups
# VDone
# Done -3.62611e-10 -103.8255033557047
# Ups
# VDone
# Done -3.73431e-10 -102.08053691275168
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.46881e-10 -98.59060402684564
# Ups
# VDone
# Done -3.4513e-10 -96.84563758389262
# Ups
# VDone
# Done -3.5253e-10 -95.1006711409396
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.45721e-10 -91.61073825503357
# Ups
# VDone
# Done -3.63241e-10 -89.86577181208054
# Ups
# VDone
# Done -3.42895e-10 -88.12080536912751
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.52328e-10 -84.63087248322148
# Ups
# VDone
# Done -3.40326e-10 -82.88590604026845
# Ups
# VDone
# Done -3.43834e-10 -81.14093959731544
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.50888e-10 -77.6510067114094
# Ups
# VDone
# Done -2.95945e-10 -75.90604026845638
# Ups
# VDone
# Done -3.43603e-10 -74.16107382550337
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.22101e-10 -70.67114093959731
# Ups
# VDone
# Done -3.53215e-10 -68.92617449664431
# Ups
# VDone
# Done -3.3658e-10 -67.18120805369128
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -3.00399e-10 -63.691275167785236
# Ups
# VDone
# Done -2.67842e-10 -61.94630872483222
# Ups
# VDone
# Done -2.65936e-10 -60.20134228187919
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -2.17059e-10 -56.71140939597316
# Ups
# VDone
# Done -2.18964e-10 -54.966442953020135
# Ups
# VDone
# Done -2.17777e-10 -53.22147651006712
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.87464e-10 -49.73154362416108
# Ups
# VDone
# Done -1.7959e-10 -47.98657718120806
# Ups
# VDone
# Done -1.8015e-10 -46.241610738255034
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.66515e-10 -42.75167785234899
# Ups
# VDone
# Done -1.67206e-10 -41.006711409395976
# Ups
# VDone
# Done -1.67557e-10 -39.26174496644296
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.60258e-10 -35.77181208053692
# Ups
# VDone
# Done -1.59908e-10 -34.026845637583904
# Ups
# VDone
# Done -1.60931e-10 -32.281879194630875
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.55298e-10 -28.79194630872483
# Ups
# VDone
# Done -1.55728e-10 -27.046979865771817
# Ups
# VDone
# Done -1.55661e-10 -25.302013422818803
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.52853e-10 -21.81208053691276
# Ups
# VDone
# Done -1.5233e-10 -20.06711409395973
# Ups
# VDone
# Done -1.52535e-10 -18.322147651006716
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.46892e-10 -14.832214765100673
# Ups
# VDone
# Done -1.46937e-10 -13.087248322147659
# Ups
# VDone
# Done -1.47863e-10 -11.34228187919463
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.38657e-10 -7.852348993288601
# Ups
# VDone
# Done -1.39914e-10 -6.107382550335572
# Ups
# VDone
# Done -1.40018e-10 -4.362416107382558
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done -1.1542e-10 -0.8724832214765286
# Ups
# VDone
# Done -1.16399e-10 0.8724832214765001
# Ups
# VDone
# Done -1.17274e-10 2.617449664429529
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 6.619e-11 6.107382550335558
# Ups
# VDone
# Done 6.39202e-11 7.852348993288587
# Ups
# VDone
# Done 6.22692e-11 9.597315436241615
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 8.95837e-11 13.087248322147644
# Ups
# VDone
# Done 8.81195e-11 14.832214765100673
# Ups
# VDone
# Done 8.6657e-11 16.577181208053673
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 9.77099e-11 20.06711409395973
# Ups
# VDone
# Done 9.6634e-11 21.81208053691273
# Ups
# VDone
# Done 9.59663e-11 23.55704697986576
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.09919e-10 27.046979865771817
# Ups
# VDone
# Done 1.08547e-10 28.791946308724818
# Ups
# VDone
# Done 1.0728e-10 30.536912751677846
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.24674e-10 34.026845637583875
# Ups
# VDone
# Done 1.26586e-10 35.771812080536904
# Ups
# VDone
# Done 1.25573e-10 37.51677852348993
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.49541e-10 41.00671140939596
# Ups
# VDone
# Done 1.51626e-10 42.75167785234899
# Ups
# VDone
# Done 1.47076e-10 44.49664429530202
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 1.76724e-10 47.98657718120805
# Ups
# VDone
# Done 1.80209e-10 49.73154362416108
# Ups
# VDone
# Done 1.82348e-10 51.47651006711408
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 2.11973e-10 54.966442953020135
# Ups
# VDone
# Done 2.11923e-10 56.711409395973135
# Ups
# VDone
# Done 2.20885e-10 58.456375838926164
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 2.60953e-10 61.94630872483219
# Ups
# VDone
# Done 2.61711e-10 63.69127516778522
# Ups
# VDone
# Done 2.57512e-10 65.43624161073825
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.09315e-10 68.92617449664428
# Ups
# VDone
# Done 2.97541e-10 70.67114093959731
# Ups
# VDone
# Done 2.90863e-10 72.41610738255034
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.32425e-10 75.90604026845637
# Ups
# VDone
# Done 3.35804e-10 77.6510067114094
# Ups
# VDone
# Done 3.31564e-10 79.3959731543624
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.5673e-10 82.88590604026845
# Ups
# VDone
# Done 3.60048e-10 84.63087248322148
# Ups
# VDone
# Done 3.59741e-10 86.37583892617448
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.79274e-10 89.86577181208054
# Ups
# VDone
# Done 3.80471e-10 91.61073825503354
# Ups
# VDone
# Done 3.75717e-10 93.35570469798657
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 3.95234e-10 96.8456375838926
# Ups
# VDone
# Done 3.88375e-10 98.59060402684563
# Ups
# VDone
# Done 3.90983e-10 100.33557046979865
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 4.02627e-10 103.82550335570468
# Ups
# VDone
# Done 4.0302e-10 105.57046979865771
# Ups
# VDone
# Done 3.96993e-10 107.31543624161074
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 4.14079e-10 110.80536912751677
# Ups
# VDone
# Done 4.05953e-10 112.5503355704698
# Ups
# VDone
# Done 4.12684e-10 114.2953020134228
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 4.16025e-10 117.78523489932886
# Ups
# VDone
# Done 4.14817e-10 119.53020134228186
# Ups
# VDone
# Done 4.12623e-10 121.27516778523488
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# VDone
# Done 4.24152e-10 124.76510067114094
# Ups
# VDone
# Done 4.20703e-10 126.51006711409394
# Ups
# VDone
# Done 4.17927e-10 128.25503355704694
# Ups
# VDone
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I
# Ups I

# %%
SMALL_SIZE = 20
MEDIUM_SIZE = 25
BIGGER_SIZE = 30

plt.rc('font', family='Arial', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title
plt.rc('grid', linestyle='--')
plt.rc('grid', color='#B20202')

# %%
plt.plot(Vs_blue[2:], np.array(Is_blue[2:]) * 1e9, 'navy')
#plt.plot(Vs0, Is0, 'blue')
plt.plot(Vs0[-150:], np.array(Is0[-150:]) * 1e9, 'black')
plt.plot(Vs_green[2:], np.array(Is_green[2:]) * 1e9, 'green')
plt.ylabel("Current, nA")
plt.xlabel("Voltage, V")
plt.grid(alpha=0.1)

# %%
iv = smu._measure_linear_sweep(channel='a', unit='v', start_value=-130, stop_value=130, settling_time=0.5, points=100)

# %%
iv
# Out:
# [[9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37], [9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37, 9.91e+37]]

# %%
smu._measure('a', 'i')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:630, in SMU26xx.__check_error_queue(self)
#     629 try:
# --> 630     [code, message] = response.split('\t', 1)
#     631     if float(code) != 0:
#     632         # if we have an error code something happened and we should raise an error
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 smu._measure('a', 'i')
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:980, in SMU26xx._measure(self, channel, unit)
#     977 else:
#     978     cmd = 'print(smu' + str(channel) + '.measure.' + str(unit) + '())'
# --> 980 reading = self.query_lua(cmd)
#     981 reading = reading.replace("'", "")
#     982 # if we get more than one value out then put it in a list
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:673, in SMU26xx.query_lua(self, cmd, check_for_errors)
#     671 # check if the command executed without any errors
#     672 if check_for_errors:
# --> 673     self.__check_error_queue()
#     674 return reading
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:635, in SMU26xx.__check_error_queue(self)
#     633         raise ValueError('The SMU said: "' + str(message) + '"  /  Keithley-Error-Code: ' + str(code))
#     634 except:
# --> 635     raise ValueError('The SMU said: "' + str(response))
#
# ValueError: The SMU said: "4.32458e-10

# %%
smu_a.set_voltage(-190
                  )

# %%
Is_backwards
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 1.04522e-10, 1.04841e-10, 1.06151e-10, 1.0689e-10, 1.07119e-10, 1.0238e-10, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, -1.03131e-10, -1.02218e-10, -1.01672e-10, -1.01773e-10, -1.01705e-10, -1.0128e-10, None, -1.22572e-10, -1.21665e-10, -1.20354e-10, -1.19334e-10, -1.18722e-10, -1.1885e-10, None, -1.30183e-10, -1.29823e-10, -1.29608e-10, -1.2871e-10, -1.27401e-10, -1.26962e-10, None, -1.54046e-10, -1.51212e-10, -1.50595e-10, -1.48799e-10, -1.48691e-10, -1.50969e-10, None, -2.93988e-10, -2.95744e-10, -2.9531e-10, -2.93922e-10, -2.95926e-10, -2.96261e-10, None, -3.85415e-10]

# %%
plt.plot(volts, Is_backwards)
plt.plot(volts, Is_forward)

# %%
smu.measure_current()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:633, in SMU26xx.__check_error_queue(self)
#     631     if float(code) != 0:
#     632         # if we have an error code something happened and we should raise an error
# --> 633         raise ValueError('The SMU said: "' + str(message) + '"  /  Keithley-Error-Code: ' + str(code))
#     634 except:
#
# ValueError: The SMU said: "-4.41074e-16
# "  /  Keithley-Error-Code: 5.67170e-12
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 smu.measure_current()
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:789, in SMU26xx.measure_current(self)
#     772 def measure_current(self):
#     773     """
#     774     Causes the SMU to trigger a current measurement and return a single reading for both channels (if available).
#     775     Use this function if you need exact time correlation between the current of the two channels.
#    (...)
#     787         ValueError: If the SMU has just one channel
#     788     """
# --> 789     return self._measure(SMU26xx.CHANNEL_ALL, SMU26xx.UNIT_CURRENT)
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:980, in SMU26xx._measure(self, channel, unit)
#     977 else:
#     978     cmd = 'print(smu' + str(channel) + '.measure.' + str(unit) + '())'
# --> 980 reading = self.query_lua(cmd)
#     981 reading = reading.replace("'", "")
#     982 # if we get more than one value out then put it in a list
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:673, in SMU26xx.query_lua(self, cmd, check_for_errors)
#     671 # check if the command executed without any errors
#     672 if check_for_errors:
# --> 673     self.__check_error_queue()
#     674 return reading
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:635, in SMU26xx.__check_error_queue(self)
#     633         raise ValueError('The SMU said: "' + str(message) + '"  /  Keithley-Error-Code: ' + str(code))
#     634 except:
# --> 635     raise ValueError('The SMU said: "' + str(response))
#
# ValueError: The SMU said: "5.67170e-12	-4.41074e-16

# %%
smu._reset()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 smu._reset()
#
# TypeError: SMU26xx._reset() missing 1 required positional argument: 'channel'

# %%
smu.UNIT_VOLTAGE
# Out:
# 'v'

# %%
smu._set_level("a", smu.UNIT_VOLTAGE, -25)

# %%
smu.measure_voltage()
# Out:
# [-0.00209808, -5.97239e-05]

# %%
smu_a.identify()
# Out:
# '2636B Channel A'

# %%
smu.get_available_current_ranges()
# Out:
# [1e-09, 1e-08, 1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 1.5]

# %%
smu_a = smu.get_channel('a')

# %%
smu_a.set_voltage(-100)

# %%
smu_a.enable_output()

# %%
smu_a.disable_output()

# %%
smu_a.measure_voltage()
# Out:
# -0.00169277

# %%
smu_a.set_current_range(0.001)

# %%
smu_a.measure_current()
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 smu_a.measure_current()
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:392, in _SMUChannel.measure_current(self)
#     385 def measure_current(self):
#     386     """
#     387     Causes the SMU to trigger a current measurement and return a single reading.
#     388
#     389     Returns:
#     390         float: the value of the reading in ampere
#     391     """
# --> 392     return self.__smu._measure(self.__channel, SMU26xx.UNIT_CURRENT)
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:980, in SMU26xx._measure(self, channel, unit)
#     977 else:
#     978     cmd = 'print(smu' + str(channel) + '.measure.' + str(unit) + '())'
# --> 980 reading = self.query_lua(cmd)
#     981 reading = reading.replace("'", "")
#     982 # if we get more than one value out then put it in a list
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:668, in SMU26xx.query_lua(self, cmd, check_for_errors)
#     666     print('Query cmd: ' + str(cmd))
#     667 # send the request to the device
# --> 668 reading = self.__instrument.query(str(cmd)).rstrip('\r\n')
#     669 if self.__debug:
#     670     print('Query answer: ' + str(reading))
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:647, in MessageBasedResource.query(self, message, delay)
#     644 if delay > 0.0:
#     645     time.sleep(delay)
# --> 647 return self.read()
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:485, in MessageBasedResource.read(self, termination, encoding)
#     483 if termination is None:
#     484     termination = self._read_termination
# --> 485     message = self._read_raw().decode(enco)
#     486 else:
#     487     with self.read_termination_context(termination):
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:441, in MessageBasedResource._read_raw(self, size)
#     434     while status == loop_status:
#     435         logger.debug(
#     436             "%s - reading %d bytes (last status %r)",
#     437             self._resource_name,
#     438             size,
#     439             status,
#     440         )
# --> 441         chunk, status = self.visalib.read(self.session, size)
#     442         ret.extend(chunk)
#     443 except errors.VisaIOError as e:
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\functions.py:2336, in read(library, session, count)
#    2334 buffer = create_string_buffer(count)
#    2335 return_count = ViUInt32()
# -> 2336 ret = library.viRead(session, buffer, count, byref(return_count))
#    2337 return buffer.raw[: return_count.value], ret
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\highlevel.py:226, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     223         # Set session back to a safe value
#     224         session = None
# --> 226 return self.handle_return_value(session, ret_value)
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
smu_a.identify()
# Out:
# '2636B Channel A'

# %%
# Out:
# 0.495839

# %%
smu_a.set_mode_voltage_source()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:633, in SMU26xx.__check_error_queue(self)
#     631     if float(code) != 0:
#     632         # if we have an error code something happened and we should raise an error
# --> 633         raise ValueError('The SMU said: "' + str(message) + '"  /  Keithley-Error-Code: ' + str(code))
#     634 except:
#
# ValueError: The SMU said: "TSP Runtime error at line 1: attempt to index global `smuA' (a nil value)
# "  /  Keithley-Error-Code: -2.86000e+02
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 smu_a.set_mode_voltage_source()
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:65, in _SMUChannel.set_mode_voltage_source(self)
#      59 def set_mode_voltage_source(self):
#      60     """
#      61     Sets the channel into voltage source mode.
#      62
#      63     In this mode you set the voltage and can measure current, resistance and power.
#      64     """
# ---> 65     self.__smu._set_mode(self.__channel, SMU26xx.VOLTAGE_MODE)
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:874, in SMU26xx._set_mode(self, channel, mode)
#     872 def _set_mode(self, channel, mode):
#     873     cmd = 'smu' + str(channel) + '.source.func = ' + 'smu' + str(channel) + '.OUTPUT_' + str(mode)
# --> 874     self.write_lua(cmd)
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:652, in SMU26xx.write_lua(self, cmd, check_for_errors)
#     650 # check if the command executed without any errors
#     651 if check_for_errors:
# --> 652     self.__check_error_queue()
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:635, in SMU26xx.__check_error_queue(self)
#     633         raise ValueError('The SMU said: "' + str(message) + '"  /  Keithley-Error-Code: ' + str(code))
#     634 except:
# --> 635     raise ValueError('The SMU said: "' + str(response))
#
# ValueError: The SMU said: "-2.86000e+02	TSP Runtime error at line 1: attempt to index global `smuA' (a nil value)

# %%
set_voltage(0)
# Out:
# 1

# %%
smu.measure_current()
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 smu.measure_current()
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:789, in SMU26xx.measure_current(self)
#     772 def measure_current(self):
#     773     """
#     774     Causes the SMU to trigger a current measurement and return a single reading for both channels (if available).
#     775     Use this function if you need exact time correlation between the current of the two channels.
#    (...)
#     787         ValueError: If the SMU has just one channel
#     788     """
# --> 789     return self._measure(SMU26xx.CHANNEL_ALL, SMU26xx.UNIT_CURRENT)
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:980, in SMU26xx._measure(self, channel, unit)
#     977 else:
#     978     cmd = 'print(smu' + str(channel) + '.measure.' + str(unit) + '())'
# --> 980 reading = self.query_lua(cmd)
#     981 reading = reading.replace("'", "")
#     982 # if we get more than one value out then put it in a list
#
# File c:\Users\yy3\GIT\squdi\src\qudi\jupyternotebooks\keithley2600.py:668, in SMU26xx.query_lua(self, cmd, check_for_errors)
#     666     print('Query cmd: ' + str(cmd))
#     667 # send the request to the device
# --> 668 reading = self.__instrument.query(str(cmd)).rstrip('\r\n')
#     669 if self.__debug:
#     670     print('Query answer: ' + str(reading))
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:647, in MessageBasedResource.query(self, message, delay)
#     644 if delay > 0.0:
#     645     time.sleep(delay)
# --> 647 return self.read()
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:485, in MessageBasedResource.read(self, termination, encoding)
#     483 if termination is None:
#     484     termination = self._read_termination
# --> 485     message = self._read_raw().decode(enco)
#     486 else:
#     487     with self.read_termination_context(termination):
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py:441, in MessageBasedResource._read_raw(self, size)
#     434     while status == loop_status:
#     435         logger.debug(
#     436             "%s - reading %d bytes (last status %r)",
#     437             self._resource_name,
#     438             size,
#     439             status,
#     440         )
# --> 441         chunk, status = self.visalib.read(self.session, size)
#     442         ret.extend(chunk)
#     443 except errors.VisaIOError as e:
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\functions.py:2336, in read(library, session, count)
#    2334 buffer = create_string_buffer(count)
#    2335 return_count = ViUInt32()
# -> 2336 ret = library.viRead(session, buffer, count, byref(return_count))
#    2337 return buffer.raw[: return_count.value], ret
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\highlevel.py:226, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     223         # Set session back to a safe value
#     224         session = None
# --> 226 return self.handle_return_value(session, ret_value)
#
# File ~\Anaconda3\envs\squdi\lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os
from collections import namedtuple
import time
import os
import time
import numpy as np
from tqdm import tqdm
from tqdm.auto import tqdm # Import tqdm for progress bars
from toptica.lasersdk.dlcpro.v2_0_3 import DLCpro, NetworkConnection

# %%
def save_ple(tag, poi_name=None, folder_name = None):
        if folder_name:
            ple_gui._save_folderpath = folder_name
            ple_gui.save_path_widget.currPathLabel.setText(ple_gui._save_folderpath)
        ple_gui.save_path_widget.saveTagLineEdit.setText(
            f"{tag}"
            )
        ple_gui._mw.actionSave.triggered.emit()

# %%
field_targets = np.linspace(-200, 200, 200)

# %%
output_folder = r'Z:\Vlad\heavyIV\250\electrodes2'

# %%
def repump_with_green(duration=1):
    switch_combiner_interfuse.set_state(switch="GreenBF", state="On")
    switch_combiner_interfuse.set_state(switch="ResonantBF", state="Off")
    time.sleep(duration)
    switch_combiner_interfuse.set_state(switch="GreenBF", state="Off")
    switch_combiner_interfuse.set_state(switch="ResonantBF", state="On")

# %%
ple_gui._fit_averaged = False
with DLCpro(NetworkConnection(dl_pro.tcp_address)) as dlc:
    dlc.laser1.wide_scan.trigger.output_enabled.set(True)
    dlc.laser1.wide_scan.continuous_mode.set(False)
while laser_scanner_logic.module_state()=='locked':
    ple_gui._mw.actionToggle_scan.setChecked(False)
    time.sleep(0.25)
    ple_gui.toggle_scan()
    time.sleep(1)

time.sleep(1)
ple_gui._mw.number_of_repeats_SpinBox.editingFinished.emit()
time.sleep(0.5)
ple_gui._mw.number_of_repeats_SpinBox.editingFinished.emit()
time.sleep(0.5)
ple_gui._mw.actionToggle_scan.setChecked(True)
time.sleep(0.5)
ple_gui.toggle_scan()
time.sleep(0.5)


centers = []
with DLCpro(NetworkConnection(dl_pro.tcp_address)) as dlc:
    dlc.laser1.wide_scan.trigger.output_enabled.set(True)
ple_gui._fit_averaged = False
ple_gui._mw.number_of_repeats_SpinBox.setValue(field_targets.shape[0])
time.sleep(1)
ple_gui._mw.number_of_repeats_SpinBox.editingFinished.emit()
time.sleep(1)
ple_gui._mw.number_of_repeats_SpinBox.editingFinished.emit()
if ple_gui._mw.number_of_repeats_SpinBox.value() == field_targets.shape[0] + 1:
    
    ple_gui._mw.actionToggle_scan.setChecked(True)
    time.sleep(0.25)
    ple_gui.toggle_scan()
else:
    ple_gui._mw.number_of_repeats_SpinBox.setValue(field_targets.shape[0] + 1)
    time.sleep(1)
    ple_gui._mw.number_of_repeats_SpinBox.editingFinished.emit()
    time.sleep(1)
    ple_gui._mw.number_of_repeats_SpinBox.editingFinished.emit()

for i, field_target in enumerate(field_targets):
    repump_with_green(1)
    set_voltage(field_target)
    #print("✅ Field reached:", field_target)
    with DLCpro(NetworkConnection(dl_pro.tcp_address)) as dlc:
        
        time.sleep(1)
        dlc.laser1.wide_scan.continuous_mode.set(False)
        dlc.laser1.wide_scan.trigger.output_enabled.set(True)

        laser_state = dlc._laser1.wide_scan.state.get()
        if laser_state == 0:
            dlc._laser1.wide_scan.start()
        time.sleep(0.5)
        laser_state = dlc._laser1.wide_scan.state.get()
        time.sleep(0.5)
        while laser_state != 0:
            time.sleep(1)
            laser_state = dlc._laser1.wide_scan.state.get()
        time.sleep(1)
        dlc.laser1.wide_scan.trigger.output_enabled.set(False)
        

tag = f"Voltage_sweep22"
save_ple(tag=tag, poi_name=None, folder_name=output_folder)
# Save the array of target fields in the output folder
np.savetxt(os.path.join(output_folder, "field_targets.csv"), field_targets, delimiter=",", comments="")

# %%
import numpy as np
import time

# %%
poi_manager_logic.poi_names
# Out:
# ['SnV_1', 'SnV_2', 'SnV_3', 'SnV_4', 'SnV_5', 'SnV_6', 'SnV_7', 'SnV_8', 'SnV_9', 'SnV_10', 'SnV_11', 'SnV_12', 'SnV_13', 'SnV_14', 'SnV_15', 'SnV_16', 'SnV_17', 'SnV_18', 'SnV_19', 'SnV_20', 'SnV_21', 'SnV_22', 'SnV_23', 'SnV_24', 'SnV_25', 'SnV_26', 'SnV_27', 'SnV_28', 'SnV_29', 'SnV_30', 'SnV_31', 'SnV_32', 'SnV_33', 'SnV_34', 'SnV_35', 'SnV_36', 'SnV_37', 'SnV_38', 'SnV_39', 'SnV_40', 'SnV_41']

# %%
pois = poi_manager_logic.poi_names
for poi in pois:
    print(f"Measuring {poi}")
    poi_manager_logic.go_to_poi(poi)
    time.sleep(1)
    spectrometerlogic.run_get_spectrum()
    time.sleep(130)
    spectrometerlogic.save_spectrum_data(False, f"{poi}_wg_12_60keV", spectrometer._save_folderpath)
# Out:
# Measuring SnV_1
# Measuring SnV_2
# Measuring SnV_3
# Measuring SnV_4
# Measuring SnV_5
# Measuring SnV_6
# Measuring SnV_7
# Measuring SnV_8
# Measuring SnV_9
# Measuring SnV_10
# Measuring SnV_11
# Measuring SnV_12
# Measuring SnV_13
# Measuring SnV_14
# Measuring SnV_15
# Measuring SnV_16
# Measuring SnV_17
# Measuring SnV_18
# Measuring SnV_19
# Measuring SnV_20
# Measuring SnV_21
# Measuring SnV_22
# Measuring SnV_23
# Measuring SnV_24
# Measuring SnV_25
# Measuring SnV_26
# Measuring SnV_27
# Measuring SnV_28
# Measuring SnV_29
# Measuring SnV_30
# Measuring SnV_31
# Measuring SnV_32
# Measuring SnV_33
# Measuring SnV_34
# Measuring SnV_35
# Measuring SnV_36
# Measuring SnV_37
# Measuring SnV_38
# Measuring SnV_39
# Measuring SnV_40
# Measuring SnV_41

# %%
poi_manager_logic.go_to_poi('SnV_1')

# %%
dir(spectrometerlogic)
# Out:
# ['_Base__activation_callback', '_Base__deactivation_callback', '_Base__initialize_config_options', '_Base__initialize_connectors', '_Base__logger', '_Base__qudi_main_weakref', '__METAOBJECT__', '__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_abc_impl', '_acquisition_running', '_axis_type_frequency', '_background', '_background_correction', '_constant_acquisition', '_default_fit_configs', '_differential_spectrum', '_dump_status_variables', '_fit_config', '_fit_config_model', '_fit_container', '_fit_method', '_fit_region', '_fit_results', '_get_si_scaling', '_load_status_variables', '_lock', '_meta', '_qudi_main', '_repetitions_background', '_repetitions_spectrum', '_send_balloon_messa
# ...

# %%
spectrometerlogic.run_get_spectrum()

# %%
spectrometerlogic.save_spectrum_data('bla')

# %%
dir(spectrometer)
# Out:
# ['_Base__activation_callback', '_Base__deactivation_callback', '_Base__initialize_config_options', '_Base__initialize_connectors', '_Base__logger', '_Base__qudi_main_weakref', '_GuiBase__window_geometry', '_GuiBase__window_state', '__METAOBJECT__', '__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_abc_impl', '_delete_fit', '_dump_status_variables', '_fsd', '_load_status_variables', '_meta', '_mw', '_progress_poll_interval', '_progress_timer', '_qudi_main', '_restore_window_geometry', '_save_folderpath', '_save_window_geometry', '_send_balloon_message', '_send_pop_up_message', '_spectrometer_logic', '_start_acquisition_timestamp', '_target_x', '_threaded', '_update_progress_bar', 'acqui
# ...

# %%
spectrometerlogic.save_spectrum_data(True, 'test', spectrometer._save_folderpath)

# %%
import time
from matplotlib import pyplot as plt

# %%
flip_mirror_switch_ni.set_state
# Out:
# <qudi.hardware.switches.digital_switch_ni.DigitalSwitchNI(0x18f8078c4c0) at 0x0000018FFF380CC0>

# %%
flip_mirror_switch_ni.set_state('Mirror', 'On')

# %%
spectrometer.acquire_spectrum()
while spectrometerlogic._acquisition_running:
    time.sleep(1)
time.sleep(0.1)
spectrometer.save_widget.saveTagLineEdit.setText('def1')
spectrometer.save_spectrum()

# %%
scanning_optimize_logic.start_optimize()
while scanning_optimize_logic.module_state()=='locked':
    time.sleep(1) # wait for a long time to

# %%
import numpy as np

def create_2d_grid(x_min, x_max, y_min, y_max, x_res, y_res):
    """
    Create a 2D grid within the specified boundaries and resolution.

    Parameters:
    x_min (float): Minimum x boundary.
    x_max (float): Maximum x boundary.
    y_min (float): Minimum y boundary.
    y_max (float): Maximum y boundary.
    x_res (int): Number of points along the x-axis.
    y_res (int): Number of points along the y-axis.

    Returns:
    tuple: Arrays representing the x and y coordinates of the grid.
    """
    x = np.linspace(x_min, x_max, x_res)
    y = np.linspace(y_min, y_max, y_res)
    x_grid, y_grid = np.meshgrid(x, y)
    
    return x_grid, y_grid

# Example usage:
x_min, x_max = -12e-6, 7e-6
y_min, y_max = -5e-6, 10e-6
x_res, y_res = 20, 20

x_grid, y_grid = create_2d_grid(x_min, x_max, y_min, y_max, x_res, y_res)

# Plotting the grid
plt.figure(figsize=(8, 8))
plt.plot(x_grid, y_grid, 'k-', alpha=0.7)  # Plot horizontal lines
plt.plot(x_grid.T, y_grid.T, 'k-', alpha=0.7)  # Plot vertical lines
plt.scatter(x_grid, y_grid, color='red')  # Mark grid points
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D Grid')
plt.grid(True)
plt.show()

# %%
galvo_scanning_probe_logic.scanner_target
# Out:
# {'x': -1.2e-05, 'y': -3.4211e-06}

# %%
current_pos = galvo_scanning_probe_logic.scanner_target
new_pos = current_pos.copy()

# Flatten the grid arrays for easier iteration
x_flat = x_grid.flatten()
y_flat = y_grid.flatten()

for idx, (x, y) in enumerate(zip(x_flat, y_flat)):
    
    
    time.sleep(0.2)
    galvo_scanning_probe_logic.set_target_position(
        
            {'x':x, 'y':y}
        
    )
    time.sleep(0.2)
    if idx % 5 == 0:
        print(f'At point {idx} / {x_flat.size}')
     
    spectrometer.acquire_spectrum()
    time.sleep(20)
    spectrometerlogic._acquisition_running
    # Wait until the spectrum acquisition is complete
    
    
    time.sleep(0.25)  # Short delay before saving
    
    # Set the save tag and save the spectrum
    spectrometer.save_widget.saveTagLineEdit.setText(f'def{idx}')
    spectrometer.save_spectrum()
# Out:
# At point 0 / 400
# At point 5 / 400
# At point 10 / 400
# At point 15 / 400
# At point 20 / 400
# At point 25 / 400
# At point 30 / 400
# At point 35 / 400
# At point 40 / 400
# At point 45 / 400
# At point 50 / 400
# At point 55 / 400
# At point 60 / 400
# At point 65 / 400
# At point 70 / 400
# At point 75 / 400
# At point 80 / 400
# At point 85 / 400
# At point 90 / 400
# At point 95 / 400
# At point 100 / 400
# At point 105 / 400
# At point 110 / 400
# At point 115 / 400
# At point 120 / 400
# At point 125 / 400
# At point 130 / 400
# At point 135 / 400
# At point 140 / 400
# At point 145 / 400
# At point 150 / 400
# At point 155 / 400
# At point 160 / 400
# At point 165 / 400
# At point 170 / 400
# At point 175 / 400
# At point 180 / 400
# At point 185 / 400
# At point 190 / 400
# At point 195 / 400
# At point 200 / 400
# At point 205 / 400
# At point 210 / 400
# At point 215 / 400
# At point 220 / 400
# At point 225 / 400
# At point 230 / 400
# At point 235 / 400
# At point 240 / 400
# At point 245 / 400
# At point 250 / 400
# At point 255 / 400
# At point 260 / 400
# At point 265 / 400
# At point 270 / 400
# At point 275 / 400
# At point 280 / 400
# At point 285 / 400
# At point 290 / 400
# At point 295 / 400
# At point 300 / 400
# At point 305 / 400
# At point 310 / 400
# At point 315 / 400
# At point 320 / 400
# At point 325 / 400
# At point 330 / 400
# At point 335 / 400
# At point 340 / 400
# At point 345 / 400
# At point 350 / 400
# At point 355 / 400
# At point 360 / 400
# At point 365 / 400
# At point 370 / 400
# At point 375 / 400
# At point 380 / 400
# At point 385 / 400
# At point 390 / 400
# At point 395 / 400

# %%
   for i in range(2):
            while scanning_optimize_logic.module_state() == 'locked':
                time.sleep(1)
            scanning_optimize_logic.start_optimize()
            time.sleep(0.5)
            # Wait until the module state is no longer 'locked'
            while scanning_optimize_logic.module_state() == 'locked':
                time.sleep(1)
        
        
    while scanning_optimize_logic.module_state() == 'locked':
        time.sleep(1)

# %%
spectrometerlogic.module_state()
# Out:
# 'idle'

# %%
spectrometer.acquire_spectrum()

# %%
vanguard_laser.connect_laser()
# Out:
# True

# %%
vanguard_laser.off()
# Out:
# ---------------------------------------------------------------------------
# pyvisa.errors.VisaIOError                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 vanguard_laser.off()
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:239, in _make_method.<locals>.__call__(_self, *args, **kwargs)
#     237 def __call__(_self, *args, **kwargs):
#     238     kwargs = tuple(kwargs.items())
# --> 239     return syncreq(_self, consts.HANDLE_CALL, args, kwargs)
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      51 """Performs a synchronous request on the given proxy object.
#      52 Not intended to be invoked directly.
#      53
#    (...)
#      60 :returns: the result of the operation
#      61 """
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py:744, in Connection.sync_request(self, handler, *args)
#     741 _async_res = self.async_request(handler, *args, timeout=timeout)
#     742 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     743 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
# --> 744 return _async_res.value
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\async_.py:111, in AsyncResult.value(self)
#     109 self.wait()
#     110 if self._is_exc:
# --> 111     raise self._obj
#     112 else:
#     113     return self._obj
#
# pyvisa.errors.VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
#
# ========= Remote Traceback (1) =========
# Traceback (most recent call last):
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py", line 369, in _dispatch_request
#     res = self._HANDLERS[handler](self, *args)
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py", line 863, in _handle_call
#     return obj(*args, **dict(kwargs))
#   File "C:\Users\yy3\GIT\squdi\src\qudi\hardware\laser\vanguard_spectra_physics.py", line 134, in off
#     return float(self.inst.query('OFF'))
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py", line 647, in query
#     return self.read()
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py", line 485, in read
#     message = self._read_raw().decode(enco)
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py", line 441, in _read_raw
#     chunk, status = self.visalib.read(self.session, size)
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\functions.py", line 2336, in read
#     ret = library.viRead(session, buffer, count, byref(return_count))
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\highlevel.py", line 226, in _return_handler
#     return self.handle_return_value(session, ret_value)  # type: ignore
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\highlevel.py", line 251, in handle_return_value
#     raise errors.VisaIOError(rv)
# pyvisa.errors.VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
vanguard_laser.on()
# Out:
# ---------------------------------------------------------------------------
# pyvisa.errors.VisaIOError                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 vanguard_laser.on()
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:239, in _make_method.<locals>.__call__(_self, *args, **kwargs)
#     237 def __call__(_self, *args, **kwargs):
#     238     kwargs = tuple(kwargs.items())
# --> 239     return syncreq(_self, consts.HANDLE_CALL, args, kwargs)
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      51 """Performs a synchronous request on the given proxy object.
#      52 Not intended to be invoked directly.
#      53
#    (...)
#      60 :returns: the result of the operation
#      61 """
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py:744, in Connection.sync_request(self, handler, *args)
#     741 _async_res = self.async_request(handler, *args, timeout=timeout)
#     742 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     743 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
# --> 744 return _async_res.value
#
# File ~\miniconda3\envs\squdi\lib\site-packages\rpyc\core\async_.py:111, in AsyncResult.value(self)
#     109 self.wait()
#     110 if self._is_exc:
# --> 111     raise self._obj
#     112 else:
#     113     return self._obj
#
# pyvisa.errors.VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
#
# ========= Remote Traceback (1) =========
# Traceback (most recent call last):
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py", line 369, in _dispatch_request
#     res = self._HANDLERS[handler](self, *args)
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\rpyc\core\protocol.py", line 863, in _handle_call
#     return obj(*args, **dict(kwargs))
#   File "C:\Users\yy3\GIT\squdi\src\qudi\hardware\laser\vanguard_spectra_physics.py", line 131, in on
#     return float(self.inst.query('ON'))
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py", line 647, in query
#     return self.read()
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py", line 485, in read
#     message = self._read_raw().decode(enco)
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\resources\messagebased.py", line 441, in _read_raw
#     chunk, status = self.visalib.read(self.session, size)
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\functions.py", line 2336, in read
#     ret = library.viRead(session, buffer, count, byref(return_count))
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\ctwrapper\highlevel.py", line 226, in _return_handler
#     return self.handle_return_value(session, ret_value)  # type: ignore
#   File "C:\Users\yy3\miniconda3\envs\squdi\lib\site-packages\pyvisa\highlevel.py", line 251, in handle_return_value
#     raise errors.VisaIOError(rv)
# pyvisa.errors.VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
vanguard_laser.set_shutter_state(True)

# %%
vanguard_laser.set_shutter_state(False)

# %%
vanguard_laser.set_shutter_state(False)

# %%
scanning_probe_logic.set_target_position(
                    current_pos
                )

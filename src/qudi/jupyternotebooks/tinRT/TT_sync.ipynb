# %%
from TimeTagger import createTimeTagger, Dump, Correlation, Histogram, Counter, CountBetweenMarkers, Countrate, Combiner, TimeDifferences, scanTimeTaggerServers,createTimeTaggerNetwork
from os.path import join, getsize, isfile
from TimeTagger import *
import numpy as np

# %%
server_addresses = ["129.69.46.164:41101", "129.69.46.64:41101"]  # Replace with the IPs of the servers to connect to
ttn = createTimeTaggerNetwork(server_addresses)

# %%
ttn.getChannelList()
# Out:
# (-2008,
#  -2007,
#  -2006,
#  -2005,
#  -2004,
#  -2003,
#  -2002,
#  -2001,
#  -1008,
#  -1007,
#  -1006,
#  -1005,
#  -1004,
#  -1003,
#  -1002,
#  -1001,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  3000,
#  3001)

# %%
syncMeas = SynchronizedMeasurements(ttn)

# %%
syncMeas.stop()

# %%
syncMeas.start()

# %%
taggerSync = syncMeas.getTagger()
counter = Counter(taggerSync, [1001,2001], binwidth=1e12, n_values=1)
counter.start()
time.sleep(3)
counter.getData()

# %%
counter.start()

# %%
counter.getData()
# Out:
# array([[0],
#        [0]], dtype=int32)

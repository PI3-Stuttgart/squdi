# %%
import numpy as np
import time
from toptica.lasersdk.dlcpro.v2_0_3 import DLCpro,LaserHead,  NetworkConnection, DeviceNotFoundError
import os

# %%
import json

# %%
def set_laser_offset(v):
    with DLCpro(NetworkConnection(dl_pro.tcp_address)) as dlc:
        dlc._laser1.dl.pc.voltage_set.set(v)
    return

def save_scan(name):
    scanner_gui.save_path_widget.saveTagLineEdit.setText(name)
    scanner_gui.scan_2d_dockwidgets[('x', 'y')].scan_widget.save_scan_button.clicked.emit() #saving
    dir_ = scanning_data_logic.module_default_data_dir
    return name, dir_

# %%
ws_wavemeter.start_acquisition()
# Out:
# 0

# %%
w0 = 484.130 #THz
current_wl = ws_wavemeter.get_current_wavelength()
wavelength = (current_wl - w0) * 1e3   # to GHz

# %%
wavelength
# Out:
# 2.765342266513926

# %%
voltages = np.linspace(2, 135, 65)
w0 = 484.130 #THz

scan_names = {}
experiment_name = "scan_I_158_170kev-ref"

for voltage in voltages:
    set_laser_offset(voltage)
    time.sleep(3)
    current_wl = ws_wavemeter.get_current_wavelength()
    wavelength = (current_wl - w0) * 1e3   # to GHz
    print(wavelength)
    # Start scan and save data
    scanning_probe_logic.toggle_scan(True, ('x', 'y'))
    while scanning_probe_logic.module_state()=='locked':
            time.sleep(1)

    name, dir_ = save_scan(f"{experiment_name}_{voltage}_{wavelength:.2f}GHz")
    scan_names.update({wavelength: os.path.join(dir_, name)})

    print(f"Scan completed for {wavelength:.2f} GHz")

with open(f"{experiment_name}.txt", 'w') as file:
    json.dump(scan_names, file, indent=4)
# Out:
# -33.99028150096228
# Scan completed for -33.99 GHz
# -41.6495877910279
# Scan completed for -41.65 GHz
# -40.81139631904307
# Scan completed for -40.81 GHz
# -40.01093065460282
# Scan completed for -40.01 GHz
# -38.945401621731435
# Scan completed for -38.95 GHz
# -37.75567262965751
# Scan completed for -37.76 GHz
# -36.65578433265182
# Scan completed for -36.66 GHz
# -35.63034166046464
# Scan completed for -35.63 GHz
# -34.51875284912376
# Scan completed for -34.52 GHz
# -33.41626230337624
# Scan completed for -33.42 GHz
# -32.32479441783198
# Scan completed for -32.32 GHz
# -31.29203852614637
# Scan completed for -31.29 GHz
# -30.014471593005965
# Scan completed for -30.01 GHz
# -28.83658499848707
# Scan completed for -28.84 GHz
# -27.62038409099432
# Scan completed for -27.62 GHz
# -26.53291224038412
# Scan completed for -26.53 GHz
# -25.192836811129382
# Scan completed for -25.19 GHz
# -24.071878500080857
# Scan completed for -24.07 GHz
# -22.824835885330685
# Scan completed for -22.82 GHz
# -21.582302646720564
# Scan completed for -21.58 GHz
# -20.3321935787244
# Scan completed for -20.33 GHz
# -19.05866261756728
# Scan completed for -19.06 GHz
# -17.831655054749262
# Scan completed for -17.83 GHz
# -16.53489871318925
# Scan completed for -16.53 GHz
# -15.310205036655589
# Scan completed for -15.31 GHz
# -13.981563175150313
# Scan completed for -13.98 GHz
# -5.698993636997329
# Scan completed for -5.70 GHz
# -4.440331339822023
# Scan completed for -4.44 GHz
# -3.1519394173074033
# Scan completed for -3.15 GHz
# -1.8693739609147997
# Scan completed for -1.87 GHz
# -0.5313734600349562
# Scan completed for -0.53 GHz
# 0.6490619326768865
# Scan completed for 0.65 GHz
# 2.0061638028323614
# Scan completed for 2.01 GHz
# 3.2964232842687125
# Scan completed for 3.30 GHz
# 4.499863751505018
# Scan completed for 4.50 GHz
# 5.714314316776381
# Scan completed for 5.71 GHz
# 7.121200605638478
# Scan completed for 7.12 GHz
# 8.291976487271313
# Scan completed for 8.29 GHz
# 9.562307445889928
# Scan completed for 9.56 GHz
# 10.853512156529632
# Scan completed for 10.85 GHz
# 12.084326338992923
# Scan completed for 12.08 GHz
# 20.097838155322734
# Scan completed for 20.10 GHz
# 21.440827119988626
# Scan completed for 21.44 GHz
# 22.657473276353812
# Scan completed for 22.66 GHz
# 23.970504253156832
# Scan completed for 23.97 GHz
# 25.289784500102996
# Scan completed for 25.29 GHz
# 26.43117578924148
# Scan completed for 26.43 GHz
# 34.631183717749536
# Scan completed for 34.63 GHz
# 36.091742855035136
# Scan completed for 36.09 GHz
# 37.295933330028674
# Scan completed for 37.30 GHz
# 38.64382108082509
# Scan completed for 38.64 GHz
# 39.81895199808605
# Scan completed for 39.82 GHz
# 41.106174219066816
# Scan completed for 41.11 GHz
# 42.35008815976471
# Scan completed for 42.35 GHz
# 43.472085149289796
# Scan completed for 43.47 GHz
# 44.78000069440213
# Scan completed for 44.78 GHz
# 45.99638645504456
# Scan completed for 46.00 GHz
# 47.24865823510527
# Scan completed for 47.25 GHz
# 48.417855870582116
# Scan completed for 48.42 GHz
# 49.52225291617651
# Scan completed for 49.52 GHz
# 50.77178771813351
# Scan completed for 50.77 GHz
# 58.75179873248726
# Scan completed for 58.75 GHz
# 59.85445401904599
# Scan completed for 59.85 GHz
# 61.16071433331172
# Scan completed for 61.16 GHz
# 62.3937705914841
# Scan completed for 62.39 GHz

# %%
with open(f"{experiment_name}.txt", 'w') as file:
    json.dump(scan_names, file, indent=4)
